# %% [markdown]
# <a href="https://colab.research.google.com/github/jess-grz/AdvPython_Week4Homework/blob/main/Grzegorski_Week_1_Homework_AdvPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://chris-tea1.github.io/Upper-Steel-Arch-Bridge-in-Cyanotype/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Beginning of construction from base of bridge",
#   "date": "1898-03-14",
#   "description": "Cyanotype photo from beside Niagara River looking up at the construction of the bridge",
#   "subject": "cyanotype; construction; Upper Steel Arch Bridge; scaffolding; Niagara Gorge; Niagara Falls; Niagara River; Charles W Dill",
#   "location": "Upper Steel Arch Bridge",
#   "latitude": "43.0902",
#   "longitude": "-79.0677",
#   "format": "image/jpg",
#   "reference_url": "https://github.com/chris-tea1/Upper-Steel-Arch-Bridge-in-Cyanotype/item.html?id=item8"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://chris-tea1.github.io/Upper-Steel-Arch-Bridge-in-Cyanotype/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "abutments": 7,
#         "c.c.snyder": 1,
#         "charles w dill": 19,
#         "city hall toronto": 1,
#         "construction": 13,
#         "construction materials": 2,
#         "cyanotype": 20,
#         "electric streetcar": 1,
#         "engineers": 1,
#         "group of workers": 2,
#         "maid of the mist": 2,
#         "mills": 1,
#         "niagara falls": 13,
#         "niagara gorge": 12,
#         "niagara river": 15,
#         "pencoya co.": 1,
#         "r. khuen jr.": 1,
#         "r.s.buck": 1,
#         "rainbow bridge": 3,
#         "reverse side": 1,
#         "roadway engineers": 1,
#         "scaffolding": 7,
#         "scale": 2,
#         "steel beams": 1,
#         "steel trusses": 1,
#         "stereoscope photo card": 2,
#         "upper steel arch bridge": 21,
#         "w. winness": 1,
#         "workers": 3,
#         "workers and family members": 2
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpg": 25
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - subject
# - creator
# - format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is format. It is used 25 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                 title        date  \
# 0                 Cover Page with Photographer's Name  1897-10-27
# 1        Scaffolding under previous suspension bridge  1897-10-27
# 2                Abutments of Upper Steel Arch Bridge  1898-01-08
# 3    Group of people standing by abutments for bridge  1898-02-11
# 4                              Workers with abutments  1898-02-07
# 5                                  Man with abutments  1898-02-11
# 6     Steel trusses and beams for bridge construction  1898-03-10
# 7       Beginning of construction from base of bridge  1898-03-14
# 8     Early construction with scaffolding and workers  1898-03-16
# 9            Progress of construction three months in  1898-03-23
# 10                       View of the bridge and Falls  1898-03-23
# 11             Officials from Engineering Pencoya Co.  1898-04-01
# 12                                           CAN GANG  1898-04-13
# 13                                          N.Y. GANG  1898-04-14
# 14                     Mills seen through the Bridge   1898-04-16
# 15                              Workers on the Bridge  1898-04-21
# 16  Construction progress in April from Canadian side  1898-04-28
# 17        Construction progress in May from U.S. side  1898-05-25
# 18                           Bridge deck construction  1898-06-15
# 19                     Electric streetcar with people  1898-06-30
# 20                   Steroscope card of Niagara Falls  1903-01-01
# 21  Reverse side of Stereoscope card with pen scri...  1903-01-01
# 22                                     Rainbow Bridge  2021-12-01
# 23                                  Possible abutment  2021-12-01
# 24                               Under Rainbow Bridge  2021-12-01
#
#                                           description  \
# 0              Handwritten author's name and employer
# 1   Cyanotype photo of the scaffolding being built...
# 2   Cyanotype photo of the abutments that would su...
# 3   Cyanotype photo of a couple of people (possibl...
# 4           Cyanotype photo of workers with abutments
# 5   Cyanotype photo of a man (I suspect to be the ...
# 6   Cyanotype photo of steel trusses and beams sta...
# 7   Cyanotype photo from beside Niagara River look...
# 8   Cyanotype photo looking up at construction wit...
# 9   Cyanotype photo of further progress of constru...
# 10  Cyanotype photo of the bridge from the top of ...
# 11  Cyanotype photo of the engineers involved in t...
# 12  Cyanotype photo of a group of Canadian workers...
# 13  Cyanotype photo of a group of New York workers...
# 14  Cyanotype photo of mills as seen through the b...
# 15  Cyanotype photo of construction workers on bri...
# 16  Cyanotype photo of the bridge in April with a ...
# 17  Cyanotype photo of the bridge in May taken fro...
# 18  Cyanotype photo of workers constructing the br...
# 19  Cyanotype photo of people on and around an ele...
# 20  Steroscope card depicting Niagara Falls and a ...
# 21  The reverse side of sterescope card with a des...
# 22  Rainbow Bridge from Canadian side looking towa...
# 23  Possible remnants of abutment from previous br...
# 24                View from underneath Rainbow Bridge
#
#                                               subject  \
# 0   Charles W Dill; roadway engineers; City Hall T...
# 1   cyanotype; construction; Upper Steel Arch Brid...
# 2   cyanotype; abutments; construction; Upper Stee...
# 3   cyanotype; abutments; construction; scale; Upp...
# 4   cyanotype; abutments; construction; Upper Stee...
# 5   cyanotype; abutments; construction; Upper Stee...
# 6   cyanotype; construction; steel trusses; steel ...
# 7   cyanotype; construction; Upper Steel Arch Brid...
# 8   cyanotype; abutments; construction; scale; wor...
# 9   cyanotype; abutments; construction; Upper Stee...
# 10  cyanotype; abutments; construction; Upper Stee...
# 11  cyanotype; Upper Steel Arch Bridge; engineers;...
# 12  cyanotype; Upper Steel Arch Bridge; constructi...
# 13  cyanotype; Upper Steel Arch Bridge; constructi...
# 14  cyanotype; Upper Steel Arch Bridge; mills; con...
# 15  cyanotype; Upper Steel Arch Bridge; workers; c...
# 16  cyanotype; Upper Steel Arch Bridge; Niagara Fa...
# 17  cyanotype; Upper Steel Arch Bridge; Niagara Ri...
# 18  cyanotype; construction; workers; Upper Steel ...
# 19  cyanotype; Upper Steel Arch Bridge; electric s...
# 20  stereoscope photo card; Niagara Falls; Maid of...
# 21  reverse side; stereoscope photo card; Niagara ...
# 22  Rainbow Bridge; Niagara Falls; Niagara River; ...
# 23  Rainbow Bridge; Niagara Falls; Niagara River; ...
# 24  Rainbow Bridge; Niagara Falls; Niagara River; ...
#
#                    location latitude longitude     format  \
# 0   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 1   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 2   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 3   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 4   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 5   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 6   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 7   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 8   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 9   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 10  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 11  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 12  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 13  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 14  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 15  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 16  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 17  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 18  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 19  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 20  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 21  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 22           Rainbow Bridge  43.0902  -79.0677  image/jpg
# 23           Rainbow Bridge  43.0902  -79.0677  image/jpg
# 24           Rainbow Bridge  43.0902  -79.0677  image/jpg
#
#                                         reference_url
# 0   https://github.com/chris-tea1/Upper-Steel-Arch...
# 1   https://github.com/chris-tea1/Upper-Steel-Arch...
# 2   https://github.com/chris-tea1/Upper-Steel-Arch...
# 3   https://github.com/chris-tea1/Upper-Steel-Arch...
# 4   https://github.com/chris-tea1/Upper-Steel-Arch...
# 5   https://github.com/chris-tea1/Upper-Steel-Arch...
# 6   https://github.com/chris-tea1/Upper-Steel-Arch...
# 7   https://github.com/chris-tea1/Upper-Steel-Arch...
# 8   https://github.com/chris-tea1/Upper-Steel-Arch...
# 9   https://github.com/chris-tea1/Upper-Steel-Arch...
# 10  https://github.com/chris-tea1/Upper-Steel-Arch...
# 11  https://github.com/chris-tea1/Upper-Steel-Arch...
# 12  https://github.com/chris-tea1/Upper-Steel-Arch...
# 13  https://github.com/chris-tea1/Upper-Steel-Arch...
# 14  https://github.com/chris-tea1/Upper-Steel-Arch...
# 15  https://github.com/chris-tea1/Upper-Steel-Arch...
# 16  https://github.com/chris-tea1/Upper-Steel-Arch...
# 17  https://github.com/chris-tea1/Upper-Steel-Arch...
# 18  https://github.com/chris-tea1/Upper-Steel-Arch...
# 19  https://github.com/chris-tea1/Upper-Steel-Arch...
# 20  https://github.com/chris-tea1/Upper-Steel-Arch...
# 21  https://github.com/chris-tea1/Upper-Steel-Arch...
# 22  https://github.com/chris-tea1/Upper-Steel-Arch...
# 23  https://github.com/chris-tea1/Upper-Steel-Arch...
# 24  https://github.com/chris-tea1/Upper-Steel-Arch...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                                                title        date  \
# 22                                    Rainbow Bridge  2021-12-01
# 14                    Mills seen through the Bridge   1898-04-16
# 12                                          CAN GANG  1898-04-13
# 3   Group of people standing by abutments for bridge  1898-02-11
# 9           Progress of construction three months in  1898-03-23
# 20                  Steroscope card of Niagara Falls  1903-01-01
# 24                              Under Rainbow Bridge  2021-12-01
# 4                             Workers with abutments  1898-02-07
# 2               Abutments of Upper Steel Arch Bridge  1898-01-08
# 13                                         N.Y. GANG  1898-04-14
#
#                                           description  \
# 22  Rainbow Bridge from Canadian side looking towa...
# 14  Cyanotype photo of mills as seen through the b...
# 12  Cyanotype photo of a group of Canadian workers...
# 3   Cyanotype photo of a couple of people (possibl...
# 9   Cyanotype photo of further progress of constru...
# 20  Steroscope card depicting Niagara Falls and a ...
# 24                View from underneath Rainbow Bridge
# 4           Cyanotype photo of workers with abutments
# 2   Cyanotype photo of the abutments that would su...
# 13  Cyanotype photo of a group of New York workers...
#
#                                               subject  \
# 22  Rainbow Bridge; Niagara Falls; Niagara River; ...
# 14  cyanotype; Upper Steel Arch Bridge; mills; con...
# 12  cyanotype; Upper Steel Arch Bridge; constructi...
# 3   cyanotype; abutments; construction; scale; Upp...
# 9   cyanotype; abutments; construction; Upper Stee...
# 20  stereoscope photo card; Niagara Falls; Maid of...
# 24  Rainbow Bridge; Niagara Falls; Niagara River; ...
# 4   cyanotype; abutments; construction; Upper Stee...
# 2   cyanotype; abutments; construction; Upper Stee...
# 13  cyanotype; Upper Steel Arch Bridge; constructi...
#
#                    location latitude longitude     format  \
# 22           Rainbow Bridge  43.0902  -79.0677  image/jpg
# 14  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 12  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 3   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 9   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 20  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 24           Rainbow Bridge  43.0902  -79.0677  image/jpg
# 4   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 2   Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
# 13  Upper Steel Arch Bridge  43.0902  -79.0677  image/jpg
#
#                                         reference_url
# 22  https://github.com/chris-tea1/Upper-Steel-Arch...
# 14  https://github.com/chris-tea1/Upper-Steel-Arch...
# 12  https://github.com/chris-tea1/Upper-Steel-Arch...
# 3   https://github.com/chris-tea1/Upper-Steel-Arch...
# 9   https://github.com/chris-tea1/Upper-Steel-Arch...
# 20  https://github.com/chris-tea1/Upper-Steel-Arch...
# 24  https://github.com/chris-tea1/Upper-Steel-Arch...
# 4   https://github.com/chris-tea1/Upper-Steel-Arch...
# 2   https://github.com/chris-tea1/Upper-Steel-Arch...
# 13  https://github.com/chris-tea1/Upper-Steel-Arch...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
facet_count = cb_normalized["format"].count()
print(f"The format facet is present in {facet_count} entries.")
# Out:
# The format facet is present in 25 entries.

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
